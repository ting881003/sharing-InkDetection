# %%
import opendatasets as od
import pandas

od.download(
	"https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection/data?select=train")
# Out:
# Skipping, found downloaded files in "./vesuvius-challenge-ink-detection" (use force=True to force download)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./vesuvius-challenge-ink-detection'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ./vesuvius-challenge-ink-detection/vesuvius-challenge-ink-detection.zip
# ./vesuvius-challenge-ink-detection/sample_submission.csv
# ./vesuvius-challenge-ink-detection/test/a/mask.png
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/07.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/13.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/12.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/06.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/38.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/10.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/04.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/05.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/11.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/39.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/15.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/01.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/29.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/28.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/00.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/14.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/02.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/16.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/17.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/03.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/58.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/64.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/59.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/62.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/63.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/61.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/49.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/48.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/60.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/45.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/51.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/50.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/44.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/52.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/46.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/47.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/53.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/57.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/43.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/42.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/56.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/40.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/54.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/55.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/41.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/26.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/32.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/33.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/27.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/19.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/31.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/25.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/24.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/30.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/18.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/34.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/20.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/08.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/09.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/21.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/35.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/23.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/37.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/36.tif
# ./vesuvius-challenge-ink-detection/test/a/surface_volume/22.tif
# ./vesuvius-challenge-ink-detection/test/b/mask.png
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/07.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/13.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/12.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/06.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/38.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/10.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/04.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/05.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/11.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/39.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/15.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/01.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/29.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/28.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/00.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/14.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/02.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/16.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/17.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/03.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/58.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/64.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/59.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/62.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/63.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/61.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/49.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/48.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/60.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/45.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/51.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/50.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/44.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/52.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/46.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/47.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/53.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/57.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/43.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/42.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/56.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/40.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/54.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/55.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/41.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/26.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/32.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/33.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/27.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/19.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/31.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/25.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/24.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/30.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/18.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/34.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/20.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/08.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/09.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/21.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/35.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/23.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/37.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/36.tif
# ./vesuvius-challenge-ink-detection/test/b/surface_volume/22.tif
# ./vesuvius-challenge-ink-detection/train/1/inklabels.png
# ./vesuvius-challenge-ink-detection/train/1/ir.png
# ./vesuvius-challenge-ink-detection/train/1/inklabels_rle.csv
# ./vesuvius-challenge-ink-detection/train/1/mask.png
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/07.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/13.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/12.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/06.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/38.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/10.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/04.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/05.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/11.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/39.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/15.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/01.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/29.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/28.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/00.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/14.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/02.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/16.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/17.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/03.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/58.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/64.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/59.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/62.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/63.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/61.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/49.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/48.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/60.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/45.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/51.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/50.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/44.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/52.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/46.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/47.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/53.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/57.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/43.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/42.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/56.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/40.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/54.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/55.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/41.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/26.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/32.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/33.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/27.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/19.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/31.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/25.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/24.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/30.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/18.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/34.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/20.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/08.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/09.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/21.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/35.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/23.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/37.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/36.tif
# ./vesuvius-challenge-ink-detection/train/1/surface_volume/22.tif
# ./vesuvius-challenge-ink-detection/train/2/inklabels.png
# ./vesuvius-challenge-ink-detection/train/2/ir.png
# ./vesuvius-challenge-ink-detection/train/2/inklabels_rle.csv
# ./vesuvius-challenge-ink-detection/train/2/mask.png
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/07.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/13.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/12.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/06.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/38.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/10.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/04.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/05.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/11.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/39.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/15.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/01.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/29.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/28.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/00.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/14.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/02.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/16.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/17.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/03.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/49.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/48.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/45.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/51.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/50.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/44.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/52.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/46.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/47.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/53.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/43.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/42.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/40.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/41.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/26.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/32.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/33.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/27.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/19.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/31.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/25.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/24.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/30.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/18.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/34.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/20.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/08.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/09.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/21.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/35.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/23.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/37.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/36.tif
# ./vesuvius-challenge-ink-detection/train/2/surface_volume/22.tif

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

import glob
import time
import PIL.Image as Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tqdm import tqdm

# Data config
DATA_DIR = './vesuvius-challenge-ink-detection'
BUFFER = 32  # Half-size of papyrus patches we'll use as model inputs
Z_DIM = 20   # Number of slices in the z direction. Max value is 64 - Z_START
Z_START = 16  # Offset of slices in the z direction
SHARED_HEIGHT = 4000  # Height to resize all papyrii

# Model config
BATCH_SIZE = 32
USE_MIXED_PRECISION = False
USE_JIT_COMPILE = False

# %%
plt.imshow(Image.open(DATA_DIR + "/train/1/ir.png"), cmap="gray")

# %%
def resize(img):
    current_width, current_height = img.size
    aspect_ratio = current_width / current_height
    new_width = int(SHARED_HEIGHT * aspect_ratio)
    new_size = (new_width, SHARED_HEIGHT)
    img = img.resize(new_size)
    return img

def load_mask(split, index):
    img = Image.open(f"{DATA_DIR}/{split}/{index}/mask.png").convert('1')
    img = resize(img)
    img_array = np.array(img)
    return tf.convert_to_tensor(img_array, dtype="bool")

def load_labels(split, index):
    img = Image.open(f"{DATA_DIR}/{split}/{index}/inklabels.png")
    img = resize(img)
    img_array = np.array(img)
    return tf.convert_to_tensor(img_array, dtype="bool")

mask = load_mask(split="train", index=1)
labels = load_labels(split="train", index=1)

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_title("mask.png")
ax1.imshow(mask, cmap='gray')
ax2.set_title("inklabels.png")
ax2.imshow(labels, cmap='gray')
plt.show()

# %%
mask_test_a = load_mask(split="test", index="a")
mask_test_b = load_mask(split="test", index="b")

mask_train_1 = load_mask(split="train", index=1)
labels_train_1 = load_labels(split="train", index=1)

mask_train_2 = load_mask(split="train", index=2)
labels_train_2 = load_labels(split="train", index=2)

#mask_train_3 = load_mask(split="train", index=3)
#labels_train_3 = load_labels(split="train", index=3)

print(f"mask_test_a: {mask_test_a.shape}")
print(f"mask_test_b: {mask_test_b.shape}")
print("-")
print(f"mask_train_1: {mask_train_1.shape}")
print(f"labels_train_1: {labels_train_1.shape}")
print("-")
print(f"mask_train_2: {mask_train_2.shape}")
print(f"labels_train_2: {labels_train_2.shape}")
print("-")
#print(f"mask_train_3: {mask_train_3.shape}")
#print(f"labels_train_3: {labels_train_3.shape}")
# Out:
# mask_test_a: (4000, 9284)
# mask_test_b: (4000, 4642)
# -
# mask_train_1: (4000, 3094)
# labels_train_1: (4000, 3094)
# -
# mask_train_2: (4000, 2563)
# labels_train_2: (4000, 2563)
# -

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

ax1.set_title("labels_train_1")
ax1.imshow(labels_train_1, cmap='gray')

ax2.set_title("labels_train_2")
ax2.imshow(labels_train_2, cmap='gray')

#ax3.set_title("labels_train_3")
#ax3.imshow(labels_train_3, cmap='gray')

plt.show()

# %%
def load_volume(split, index):
    # Load the 3d x-ray scan, one slice at a time
    z_slices_fnames = sorted(glob.glob(f"{DATA_DIR}/{split}/{index}/surface_volume/*.tif"))[Z_START:Z_START + Z_DIM]
    z_slices = []
    for z, filename in  tqdm(enumerate(z_slices_fnames)):
        img = Image.open(filename)
        img = resize(img)
        z_slice = np.array(img, dtype="float32")
        z_slices.append(z_slice)
    return tf.stack(z_slices, axis=-1)

# %%
volume_train_1 = load_volume(split="train", index=1)
print(f"volume_train_1: {volume_train_1.shape}, {volume_train_1.dtype}")

volume_train_2 = load_volume(split="train", index=2)
print(f"volume_train_2: {volume_train_2.shape}, {volume_train_2.dtype}")

#volume_train_3 = load_volume(split="train", index=3)
#print(f"volume_train_3: {volume_train_3.shape}, {volume_train_3.dtype}")

#volume = tf.concat([volume_train_1, volume_train_2, volume_train_3], axis=1)
#print(f"total volume: {volume.shape}")
volume = tf.concat([volume_train_1, volume_train_2], axis=1)
print(f"total volume: {volume.shape}")

del volume_train_1
del volume_train_2
#del volume_train_3
# Out:
# 20it [00:05,  3.60it/s]
# volume_train_1: (4000, 3094, 20), <dtype: 'float32'>
# 20it [00:29,  1.45s/it]
# volume_train_2: (4000, 2563, 20), <dtype: 'float32'>
# total volume: (4000, 5657, 20)

# %%
#labels = tf.concat([labels_train_1, labels_train_2, labels_train_3], axis=1)
#print(f"labels: {labels.shape}, {labels.dtype}")

#mask = tf.concat([mask_train_1, mask_train_2, mask_train_3], axis=1)
#print(f"mask: {mask.shape}, {mask.dtype}")

labels = tf.concat([labels_train_1, labels_train_2], axis=1)
print(f"labels: {labels.shape}, {labels.dtype}")

mask = tf.concat([mask_train_1, mask_train_2], axis=1)
print(f"mask: {mask.shape}, {mask.dtype}")

# Free up memory
del labels_train_1
del labels_train_2
#del labels_train_3
del mask_train_1
del mask_train_2
#del mask_train_3
# Out:
# labels: (4000, 5657), <dtype: 'bool'>
# mask: (4000, 5657), <dtype: 'bool'>

# %%
fig, axes = plt.subplots(1, 4, figsize=(15, 3))
for z, ax in enumerate(axes):
    ax.imshow(volume[:, :, z], cmap='gray')
    ax.set_xticks([]); ax.set_yticks([])
fig.tight_layout()
plt.show()

# %%
val_location = (1400, 1000)
val_zone_size = (600, 1000)

fig, ax = plt.subplots()
ax.imshow(labels)
patch = patches.Rectangle([val_location[1], val_location[0]], val_zone_size[1], val_zone_size[0], linewidth=2, edgecolor='g', facecolor='none')
ax.add_patch(patch)
plt.show()

# %%
def sample_random_location(shape):
    random_train_x = tf.random.uniform(shape=(), minval=BUFFER, maxval=shape[0] - BUFFER - 1, dtype="int32")
    random_train_y = tf.random.uniform(shape=(), minval=BUFFER, maxval=shape[1] - BUFFER - 1, dtype="int32")
    random_train_location = tf.stack([random_train_x, random_train_y])
    return random_train_location

def is_in_masked_zone(location, mask):
    return mask[location[0], location[1]]

sample_random_location_train = lambda x: sample_random_location(mask.shape)
is_in_mask_train = lambda x: is_in_masked_zone(x, mask)

def is_in_val_zone(location, val_location, val_zone_size):
    x = location[0]
    y = location[1]
    x_match = val_location[0] - BUFFER <= x <= val_location[0] + val_zone_size[0] + BUFFER
    y_match = val_location[1] - BUFFER <= y <= val_location[1] + val_zone_size[1] + BUFFER
    return x_match and y_match

def is_proper_train_location(location):
    return not is_in_val_zone(location, val_location, val_zone_size) and is_in_mask_train(location)

train_locations_ds = tf.data.Dataset.from_tensor_slices([0]).repeat().map(sample_random_location_train, num_parallel_calls=tf.data.AUTOTUNE)
train_locations_ds = train_locations_ds.filter(is_proper_train_location)

# %%
fig, ax = plt.subplots()
ax.imshow(labels)

for x, y in train_locations_ds.take(200):
    patch = patches.Rectangle([y - BUFFER, x - BUFFER], 2 * BUFFER, 2 * BUFFER, linewidth=2, edgecolor='r', facecolor='none')
    ax.add_patch(patch)

val_patch = patches.Rectangle([val_location[1], val_location[0]], val_zone_size[1], val_zone_size[0], linewidth=2, edgecolor='g', facecolor='none')
ax.add_patch(val_patch)
plt.show()
# Out:
# 2023-05-18 10:52:42.999935: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
def extract_subvolume(location, volume):
    x = location[0]
    y = location[1]
    subvolume = volume[x-BUFFER:x+BUFFER, y-BUFFER:y+BUFFER, :]
    subvolume = tf.cast(subvolume, dtype="float32") / 65535.
    return subvolume

def extract_labels(location, labels):
    x = location[0]
    y = location[1]
    label = labels[x-BUFFER:x+BUFFER, y-BUFFER:y+BUFFER]
    label = tf.cast(label, dtype="float32")
    label = tf.expand_dims(label, axis=-1)
    return label

def extract_subvolume_and_label(location):
    subvolume = extract_subvolume(location, volume)
    label = extract_labels(location, labels)
    return subvolume, label

shuffle_buffer_size = BATCH_SIZE * 4

train_ds = train_locations_ds.map(extract_subvolume_and_label, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE).batch(BATCH_SIZE)

# %%
for subvolume_batch, label_batch in train_ds.take(1):
    print(f"subvolume shape: {subvolume_batch.shape[1:]}")
    print(f"label_batch shape: {label_batch.shape[1:]}")
# Out:
# subvolume shape: (64, 64, 20)
# label_batch shape: (64, 64, 1)

# %%
t0 = time.time()
n = 200
for _ in train_ds.take(n):
    pass
print(f"Time per batch: {(time.time() - t0) / n:.4f}s")
# Out:
# Time per batch: 0.0068s

# %%
val_locations_stride = BUFFER
val_locations = []
for x in range(val_location[0], val_location[0] + val_zone_size[0], val_locations_stride):
    for y in range(val_location[1], val_location[1] + val_zone_size[1], val_locations_stride):
        val_locations.append((x, y))

val_locations_ds = tf.data.Dataset.from_tensor_slices(val_locations).filter(is_in_mask_train)
val_ds = val_locations_ds.map(extract_subvolume_and_label, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE).batch(BATCH_SIZE)

# %%
fig, ax = plt.subplots()
ax.imshow(labels)

for x, y in val_locations_ds:
    patch = patches.Rectangle([y - BUFFER, x - BUFFER], 2 * BUFFER, 2 * BUFFER, linewidth=2, edgecolor='g', facecolor='none')
    ax.add_patch(patch)
plt.show()

# %%
def trivial_baseline(dataset):
    total = 0
    matches = 0.
    for _, batch_label in tqdm(dataset):
        matches += tf.reduce_sum(tf.cast(batch_label, "float32"))
        total += tf.reduce_prod(tf.shape(batch_label))
    return 1. - matches / tf.cast(total, "float32")

score = trivial_baseline(val_ds).numpy()
print(f"Best validation score achievable trivially: {score * 100:.2f}% accuracy")
# Out:
# 19it [00:00, 21.86it/s]
# Best validation score achievable trivially: 72.83% accuracy

# %%
augmenter = keras.Sequential([
    layers.RandomContrast(0.2),
])

def augment_train_data(data, label):
    data = augmenter(data)
    return data, label

augmented_train_ds = train_ds.map(augment_train_data, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.

# %%
def get_model(input_shape):
    inputs = keras.Input(input_shape)
    
    x = inputs
    
    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(1, 3, activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

if USE_MIXED_PRECISION:
    keras.mixed_precision.set_global_policy('mixed_float16')

model = get_model((BUFFER * 2, BUFFER * 2, Z_DIM))
model.summary()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"], jit_compile=USE_JIT_COMPILE)

model.fit(augmented_train_ds, validation_data=val_ds, epochs=20, steps_per_epoch=1000)
model.save("model.keras")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 20)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   11584       ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 32, 32, 128)  8896       ['activation[0][0]']
#  v2D)
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 128)  512        ['separable_conv2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_1[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 32, 32, 128)  17664      ['activation_1[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 128)  512        ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 128)  8320        ['batch_normalization[0][0]']
#
#  add (Add)                      (None, 16, 16, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 16, 16, 256)  34176      ['activation_2[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 256)  1024       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_3[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 16, 16, 256)  68096      ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 256)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 256)    33024       ['add[0][0]']
#
#  add_1 (Add)                    (None, 8, 8, 256)    0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 256)    0           ['add_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   590080      ['activation_4[0][0]']
#  ose)
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 8, 8, 256)   590080      ['activation_5[0][0]']
#  spose)
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0          ['add_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 256)  65792       ['up_sampling2d_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 256)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['add_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 16, 16, 128)  295040     ['activation_6[0][0]']
#  spose)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_transpose_2[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 16, 16, 128)  147584     ['activation_7[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_transpose_3[0][0]']
#  rmalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 256)  0          ['add_2[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0          ['batch_normalization_8[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  32896       ['up_sampling2d_3[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 128)  0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 128)  0           ['add_3[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_8[0][0]']
#  spose)
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_transpose_4[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 64)  36928       ['activation_9[0][0]']
#  spose)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 128)  0          ['add_3[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 64)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   8256        ['up_sampling2d_5[0][0]']
#
#  add_4 (Add)                    (None, 64, 64, 64)   0           ['up_sampling2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 1)    577         ['add_4[0][0]']
#
# ==================================================================================================
# Total params: 2,029,697
# Trainable params: 2,026,241
# Non-trainable params: 3,456
# __________________________________________________________________________________________________
# Epoch 1/20
# 1000/1000 [==============================] - 2559s 3s/step - loss: 0.4561 - accuracy: 0.8238 - val_loss: 0.6409 - val_accuracy: 0.7292
# Epoch 2/20
# 1000/1000 [==============================] - 8645s 9s/step - loss: 0.3935 - accuracy: 0.8371 - val_loss: 0.6032 - val_accuracy: 0.6961
# Epoch 3/20
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.3505 - accuracy: 0.8559 - val_loss: 0.6181 - val_accuracy: 0.7072
# Epoch 4/20
# 1000/1000 [==============================] - 754s 754ms/step - loss: 0.3113 - accuracy: 0.8721 - val_loss: 0.8558 - val_accuracy: 0.7277
# Epoch 5/20
# 1000/1000 [==============================] - 735s 734ms/step - loss: 0.2778 - accuracy: 0.8863 - val_loss: 0.6424 - val_accuracy: 0.7194
# Epoch 6/20
# 1000/1000 [==============================] - 724s 724ms/step - loss: 0.2470 - accuracy: 0.8988 - val_loss: 0.9303 - val_accuracy: 0.7122
# Epoch 7/20
# 1000/1000 [==============================] - 725s 725ms/step - loss: 0.2215 - accuracy: 0.9099 - val_loss: 0.8093 - val_accuracy: 0.6804
# Epoch 8/20
# 1000/1000 [==============================] - 734s 734ms/step - loss: 0.1972 - accuracy: 0.9200 - val_loss: 0.8917 - val_accuracy: 0.7302
# Epoch 9/20
# 1000/1000 [==============================] - 717s 717ms/step - loss: 0.1811 - accuracy: 0.9269 - val_loss: 1.0122 - val_accuracy: 0.6136
# Epoch 10/20
# 1000/1000 [==============================] - 761s 761ms/step - loss: 0.1649 - accuracy: 0.9339 - val_loss: 0.9370 - val_accuracy: 0.7203
# Epoch 11/20
# 1000/1000 [==============================] - 706s 706ms/step - loss: 0.1495 - accuracy: 0.9405 - val_loss: 1.2155 - val_accuracy: 0.7376
# Epoch 12/20
# 1000/1000 [==============================] - 714s 714ms/step - loss: 0.1385 - accuracy: 0.9450 - val_loss: 1.1848 - val_accuracy: 0.7199
# Epoch 13/20
# 1000/1000 [==============================] - 730s 730ms/step - loss: 0.1268 - accuracy: 0.9498 - val_loss: 1.5622 - val_accuracy: 0.7444
# Epoch 14/20
# 1000/1000 [==============================] - 815s 815ms/step - loss: 0.1146 - accuracy: 0.9547 - val_loss: 1.0896 - val_accuracy: 0.7410
# Epoch 15/20
# 1000/1000 [==============================] - 748s 748ms/step - loss: 0.1083 - accuracy: 0.9574 - val_loss: 1.2061 - val_accuracy: 0.6938
# Epoch 16/20
# 1000/1000 [==============================] - 763s 763ms/step - loss: 0.0975 - accuracy: 0.9615 - val_loss: 1.7916 - val_accuracy: 0.7415
# Epoch 17/20
# 1000/1000 [==============================] - 724s 724ms/step - loss: 0.0936 - accuracy: 0.9631 - val_loss: 1.2417 - val_accuracy: 0.7355
# Epoch 18/20
# 1000/1000 [==============================] - 771s 771ms/step - loss: 0.0860 - accuracy: 0.9662 - val_loss: 1.5060 - val_accuracy: 0.7369
# Epoch 19/20
# 1000/1000 [==============================] - 1077s 1s/step - loss: 0.0823 - accuracy: 0.9674 - val_loss: 1.2066 - val_accuracy: 0.7087
# Epoch 20/20
# 1000/1000 [==============================] - 712s 712ms/step - loss: 0.0789 - accuracy: 0.9689 - val_loss: 1.7222 - val_accuracy: 0.7407

# %%
del volume
del mask
del labels
del train_ds
del val_ds

# Manually trigger garbage collection
keras.backend.clear_session()
import gc
gc.collect()

model = keras.models.load_model("model.keras")

# %%
def compute_predictions_map(split, index):
    print(f"Load data for {split}/{index}")

    test_volume = load_volume(split=split, index=index)
    test_mask = load_mask(split=split, index=index)

    test_locations = []
    stride = BUFFER // 2
    for x in range(BUFFER, test_volume.shape[0] - BUFFER, stride):
        for y in range(BUFFER, test_volume.shape[1] - BUFFER, stride):
            test_locations.append((x, y))

    print(f"{len(test_locations)} test locations (before filtering by mask)")

    sample_random_location_test = lambda x: sample_random_location(test_mask.shape)
    is_in_mask_test = lambda x: is_in_masked_zone(x, test_mask)
    extract_subvolume_test = lambda x: extract_subvolume(x, test_volume)

    test_locations_ds = tf.data.Dataset.from_tensor_slices(test_locations).filter(is_in_mask_test)
    test_ds = test_locations_ds.map(extract_subvolume_test, num_parallel_calls=tf.data.AUTOTUNE)

    predictions_map = np.zeros(test_volume.shape[:2] + (1,), dtype="float16")
    predictions_map_counts = np.zeros(test_volume.shape[:2] + (1,), dtype="int8")

    print(f"Compute predictions")

    for loc_batch, patch_batch in tqdm(zip(test_locations_ds.batch(BATCH_SIZE), test_ds.batch(BATCH_SIZE))):
        predictions = model.predict_on_batch(patch_batch)
        for (x, y), pred in zip(loc_batch, predictions):
            predictions_map[x - BUFFER : x + BUFFER, y - BUFFER : y + BUFFER, :] += pred
            predictions_map_counts[x - BUFFER : x + BUFFER, y - BUFFER : y + BUFFER, :] += 1  
    predictions_map /= (predictions_map_counts + 1e-7)
    return predictions_map

# %%
predictions_map_a = compute_predictions_map(split="test", index="a")
predictions_map_b = compute_predictions_map(split="test", index="b")

# %%
from skimage.transform import resize as resize_ski

original_size_a = Image.open(DATA_DIR + "/test/a/mask.png").size
predictions_map_a = resize_ski(predictions_map_a, (original_size_a[1], original_size_a[0])).squeeze()

original_size_b = Image.open(DATA_DIR + "/test/b/mask.png").size
predictions_map_b = resize_ski(predictions_map_b, (original_size_b[1], original_size_b[0])).squeeze()

# %%
def rle(predictions_map, threshold):
    flat_img = predictions_map.flatten()
    flat_img = np.where(flat_img > threshold, 1, 0).astype(np.uint8)

    starts = np.array((flat_img[:-1] == 0) & (flat_img[1:] == 1))
    ends = np.array((flat_img[:-1] == 1) & (flat_img[1:] == 0))
    starts_ix = np.where(starts)[0] + 2
    ends_ix = np.where(ends)[0] + 2
    lengths = ends_ix - starts_ix
    return " ".join(map(str, sum(zip(starts_ix, lengths), ())))

# %%
threshold = 0.5

rle_a = rle(predictions_map_a, threshold=threshold)
rle_b = rle(predictions_map_b, threshold=threshold)
print("Id,Predicted\na," + rle_a + "\nb," + rle_b, file=open('submission.csv', 'w'))
